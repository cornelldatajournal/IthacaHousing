# %%
from homeharvest import scrape_property
from datetime import datetime

# %%
# Generate filename based on current timestamp
current_timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
filename = f"HomeHarvest_{current_timestamp}.csv"

properties = scrape_property(
  location="Ithaca Commons, Ithaca, NY",
  listing_type="for_rent",  # or (for_sale, for_rent, pending)
  past_days=90,  # sold in last 30 days - listed in last x days if (for_sale, for_rent)
    radius=400,
  # mls_only=True,  # only fetch MLS listings
  # proxy="http://user:pass@host:port"  # use a proxy to change your IP address
)
print(f"Number of properties: {len(properties)}")

# Export to csv
properties.to_csv(filename, index=False)
properties.head()
# Out:
# Number of properties: 57
#                                         property_url   mls    mls_id  \
# 0  https://www.realtor.com/realestateandhomes-det...  RNTR   8709989
# 1  https://www.realtor.com/realestateandhomes-det...  RNTR   8710070
# 2  https://www.realtor.com/realestateandhomes-det...  AVAL  60912704
# 3  https://www.realtor.com/realestateandhomes-det...  AVAL  60167274
# 4  https://www.realtor.com/realestateandhomes-det...  AVAL  60911967
#
#      status          style              street    unit    city state zip_code  \
# 0  FOR_RENT      APARTMENT  121 Cascadilla Ave   Apt 3  Ithaca    NY    14850
# 1  FOR_RENT      APARTMENT  121 Cascadilla Ave   Apt 1  Ithaca    NY    14850
# 2  FOR_RENT      APARTMENT         3 Hudson Pl  Unit B  Ithaca    NY    14850
# 3  FOR_RENT  SINGLE_FAMILY         3 Hudson Pl    None  Ithaca    NY    14850
# 4  FOR_RENT  SINGLE_FAMILY         166 Bush Ln    None  Ithaca    NY    14850
#
# ...

# %%
from redfin import Redfin

# %%
client = Redfin()

address = 'Ithaca Commons, Ithaca, NY'

response = client.search(address)
url = response['payload']['exactMatch']['url']
initial_info = client.initial_info(url)

property_id = initial_info['payload']['propertyId']
mls_data = client.below_the_fold(property_id)

listing_id = initial_info['payload']['listingId']
avm_details = client.avm_details(property_id, listing_id)
